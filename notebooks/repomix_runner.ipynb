# %% [markdown]
# <a href="https://colab.research.google.com/github/sjkim-audio/Bass-separator/blob/main/notebooks/repomix_runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !npm install -g repomix
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# added 169 packages in 18s
# ⠹
# ⠹50 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# npm install -g repomix
# rm -rf /content/Bass-separator
# git clone https://github.com/sjkim-audio/Bass-separator.git /content/Bass-separator
# cd /content/Bass-separator
# npx repomix --style xml -o "/content/drive/MyDrive/repomix-output.xml" --ignore "**/dataset/**,**/data/**,**/*.wav,**/*.mp3,**/*.pt,**/*.pth,**/*.ipynb,**/.git/**"
# Out:
# changed 169 packages in 6s
#
# 50 packages are looking for funding
#   run `npm fund` for details
#
# 📦 Repomix v1.14.0
#
# No custom config found at repomix.config.ts, repomix.config.mts, repomix.config.cts, repomix.config.js, repomix.config.mjs, repomix.config.cjs, repomix.config.json5, repomix.config.jsonc, repomix.config.json or global config at /root/.config/repomix/repomix.config.ts, /root/.config/repomix/repomix.config.mts, /root/.config/repomix/repomix.config.cts, /root/.config/repomix/repomix.config.js, /root/.config/repomix/repomix.config.mjs, /root/.config/repomix/repomix.config.cjs, /root/.config/repomix/repomix.config.json5, /root/.config/repomix/repomix.config.jsonc, /root/.config/repomix/repomix.config.json.
# You can add a config file for additional settings. Please check https://github.com/yamadashy/repomix for more information.
# ⠋ Initializing...
# ⠙ Searching for files...
# ⠹ Searching for files...
# ⠸ Searching for files...
# ⠼ Searching for files...
# ...
