# %% [markdown]
# <a href="https://colab.research.google.com/github/sjkim-audio/Bass-separator/blob/main/drive_dataset_load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
from google.colab import drive

# 1. 구글 드라이브 연결 (로그인 창이 뜨면 승인해주세요)
drive.mount('/content/drive')

# ==========================================
# [설정] 경로 지정 (여기를 본인 드라이브 폴더명에 맞게 수정!)
# ==========================================
# 구글 드라이브 내 위치 (원본 창고)
SOURCE_PATH = "/content/drive/MyDrive/Bass_separation/dataset"
# 코랩 내부 위치 (작업 공간) - 코드는 앞으로 여기를 바라봅니다.
LOCAL_PATH = "./dataset"
# ==========================================

# 2. 데이터 복사
if not os.path.exists(LOCAL_PATH):
    print(f"🚀 구글 드라이브에서 데이터를 가져오는 중...\n({SOURCE_PATH} -> {LOCAL_PATH})")
    try:
        shutil.copytree(SOURCE_PATH, LOCAL_PATH)
        print("✅ 복사 완료! 이제 데이터가 준비되었습니다.")
    except Exception as e:
        print(f"❌ 오류 발생: 경로를 확인해주세요. ({e})")
else:
    print("✅ 이미 데이터가 준비되어 있습니다 (건너뜀).")
# Out:
# Mounted at /content/drive
# 🚀 구글 드라이브에서 데이터를 가져오는 중...
# (/content/drive/MyDrive/Bass_separation/dataset -> ./dataset)
# ✅ 복사 완료! 이제 데이터가 준비되었습니다.

# %%
import os
import sys

# ------------------------------------------------------------------
# [설정] 본인의 깃허브 주소와 프로젝트 폴더명으로 수정하세요!
# ------------------------------------------------------------------
REPO_URL = "https://github.com/sjkim-audio/Bass-separator.git"
PROJECT_NAME = "Bass-separator"  # 깃허브 주소 맨 뒤의 이름 (예: guitar-bass-sep)
# ------------------------------------------------------------------

# 1. 프로젝트 폴더가 없으면 깃허브에서 통째로 가져오기 (Clone)
if not os.path.exists(PROJECT_NAME):
    print(f"🚀 깃허브에서 프로젝트를 다운로드합니다... ({PROJECT_NAME})")
    # !git clone {REPO_URL}
else:
    print("✅ 프로젝트 폴더가 이미 존재합니다.")

# 2. 파이썬이 'src' 폴더를 찾을 수 있도록 경로 추가
# (프로젝트 폴더 안으로 강제로 이동시키고, 그 위치를 등록함)
if PROJECT_NAME not in os.getcwd():
    os.chdir(PROJECT_NAME)
    print(f"📂 작업 경로 이동 완료: {os.getcwd()}")

# 시스템 경로에 현재 위치 추가
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())
# Out:
# 🚀 깃허브에서 프로젝트를 다운로드합니다... (Bass-separator)
# Cloning into 'Bass-separator'...
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 218 (delta 53), reused 33 (delta 33), pack-reused 138 (from 1)
# Receiving objects: 100% (218/218), 126.58 MiB | 22.94 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# 📂 작업 경로 이동 완료: /content/Bass-separator
# 🎉 성공! src 폴더를 찾았습니다. 이제 함수를 사용할 수 있습니다.

# %%
from src.utils import load_data_from_drive
# 3. 함수 실행! (본인의 구글 드라이브 경로를 넣으세요)
MY_DRIVE_PATH = "/content/drive/MyDrive/Bass_separation/dataset"
load_data_from_drive(MY_DRIVE_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 데이터가 이미 준비되어 있습니다.
